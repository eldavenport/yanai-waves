# %%
from dask.distributed import LocalCluster, Client
cluster = LocalCluster()
client = Client(cluster)
# Out:
# 2026-03-10 12:42:44,979 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01fa01a5c0>, <Task finished name='Task-5960325' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:45,010 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f02053eafc0>, <Task finished name='Task-5960333' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:45,012 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e3252a20>, <Task finished name='Task-5960351' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-10 12:42:45,021 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01edf9cf40>, <Task finished name='Task-5960365' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-10 12:42:45,084 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01edf9d8a0>, <Task finished name='Task-5960421' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:45,091 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01edf9e020>, <Task finished name='Task-5960423' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:45,100 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f0254b144a0>, <Task finished name='Task-5960436' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-10 12:42:45,108 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01f867ca40>, <Task finished name='Task-5960437' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-10 12:42:45,558 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e32004a0>, <Task finished name='Task-5960824' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:45,564 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f024c762520>, <Task finished name='Task-5960826' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:45,571 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01f867ca40>, <Task finished name='Task-5960828' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-10 12:42:45,577 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e3270360>, <Task finished name='Task-5960840' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-10 12:42:45,665 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01ee436660>, <Task finished name='Task-5960906' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:45,671 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01ee435300>, <Task finished name='Task-5960908' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:45,677 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e337a160>, <Task finished name='Task-5960920' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-10 12:42:45,683 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e337b420>, <Task finished name='Task-5960922' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-10 12:42:45,906 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f0254b14220>, <Task finished name='Task-5961094' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:45,913 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e3379e40>, <Task finished name='Task-5961097' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:45,919 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01edf9ee80>, <Task finished name='Task-5961109' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-10 12:42:45,926 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01edf9c180>, <Task finished name='Task-5961111' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-10 12:42:45,932 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01edf9d4e0>, <Task finished name='Task-5961113' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# ...
# 2026-03-10 12:42:47,735 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e337aca0>, <Task finished name='Task-5962638' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:47,742 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e33784a0>, <Task finished name='Task-5962640' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-10 12:42:47,749 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e337b740>, <Task finished name='Task-5962641' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-10 12:42:47,861 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01ee435300>, <Task finished name='Task-5962748' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:47,867 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01ee1f20c0>, <Task finished name='Task-5962749' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-10 12:42:47,874 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e32000e0>, <Task finished name='Task-5962756' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-10 12:42:47,880 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f01e3379e40>, <Task finished name='Task-5962764' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8

# %%
import matplotlib.pyplot as plt
import cmocean.cm as cmo
import xarray as xr
from xmitgcm import open_mdsdataset
import numpy as np

data_dir = '/data/SO3/edavenport/tpose6/apr2013/run_sens_surface/'
grid_dir = '/data/SO6/TPOSE_diags/tpose6/grid_6/'

num_diags = 122 #
itPerFile = 72 # 1 day
intervals = range(0,itPerFile*num_diags,itPerFile) # adjoint sensitivity will start at 0 and go to 1 lag (1 interval less than total number of timesteps)
prefix = ['ADJetan','ADJtaux','ADJqnet']
# when prefix is not set, this will read all available files 
# have to ignore unkown vars until we have an available_diagnostics.log that includes ADJrhoinsitu
tpose_ds = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,prefix=prefix,iters=intervals,ref_date='2013-04-01',delta_t=1200,ignore_unknown_vars=True)
tpose_ds['XC'] = tpose_ds.XC.astype(float)
tpose_ds['YC'] = tpose_ds.YC.astype(float)
tpose_ds['Z'] = tpose_ds.Z.astype(float)
tpose_ds['XG'] = tpose_ds.XG.astype(float)
tpose_ds['YG'] = tpose_ds.YG.astype(float)

# %% [markdown]
# ### Select Region

# %%
# tpose_ds.ADJetan is t, xc, yc
lat_min = -5
lat_max = 5
lon_min = 155 #170E
lon_max = 265 #100W

tpose_ds = tpose_ds.sel(XC=slice(lon_min,lon_max),YC=slice(lat_min,lat_max),XG=slice(lon_min,lon_max),YG=slice(lat_min,lat_max))

# %% [markdown]
# ### Meridional Average

# %%
ADJetan = tpose_ds.ADJetan
ADJtaux = tpose_ds.ADJtaux
ADJqnet = tpose_ds.ADJqnet

# %% [markdown]
# ### Temporal Demean and Detrend

# %%
from scipy.signal import detrend

ADJetan_detrend = detrend(ADJetan, axis=0)
ADJtaux_detrend = detrend(ADJtaux, axis=0)
ADJqnet_detrend = detrend(ADJqnet, axis=0)

# copy into data array
ADJetan_detrend = xr.DataArray(ADJetan_detrend, coords=ADJetan.coords, dims=ADJetan.dims)
ADJtaux_detrend = xr.DataArray(ADJtaux_detrend, coords=ADJtaux.coords, dims=ADJtaux.dims)
ADJqnet_detrend = xr.DataArray(ADJqnet_detrend, coords=ADJqnet.coords, dims=ADJqnet.dims)

# demean
ADJetan_anom = ADJetan_detrend - ADJetan_detrend.mean(dim='time')
ADJtaux_anom = ADJtaux_detrend - ADJtaux_detrend.mean(dim='time')
ADJqnet_anom = ADJqnet_detrend - ADJqnet_detrend.mean(dim='time')

# %% [markdown]
# ### Calculate Symmetric and Antisymmetric

# %%
# simpler: manually select +y and -y
pos = ADJetan_anom.sel(YC=ADJetan_anom.YC[ADJetan_anom.YC>=0]).values
neg = ADJetan_anom.sel(YC=ADJetan_anom.YC[ADJetan_anom.YC<=0]).values

# flip neg to align with pos
neg_flipped = neg[::-1]

# symmetric
sym = 0.5 * (pos + neg_flipped)
# antisymmetric
anti = 0.5 * (pos - neg_flipped)

ADJetan_anom_sym = xr.DataArray(sym, coords=ADJetan_anom.sel(YC=ADJetan_anom.YC[ADJetan_anom.YC>=0]).coords, dims=ADJetan_anom.sel(YC=ADJetan_anom.YC[ADJetan_anom.YC>=0]).dims)
ADJetan_anom_anti = xr.DataArray(anti, coords=ADJetan_anom.sel(YC=ADJetan_anom.YC[ADJetan_anom.YC>=0]).coords, dims=ADJetan_anom.sel(YC=ADJetan_anom.YC[ADJetan_anom.YC>=0]).dims)
ADJetan_anom_sym = ADJetan_anom_sym.mean(dim='YC')
ADJetan_anom_anti = ADJetan_anom_anti.mean(dim='YC')
ADJetan_anom = ADJetan_anom.mean(dim='YC')

# %%
ADJetan_anom_sym
# Out:
# <xarray.DataArray (time: 122, XC: 540)> Size: 264kB
# array([[ 2.6413722 ,  2.4275935 ,  2.3180397 , ...,  0.9316127 ,
#          1.0021806 ,  1.0766301 ],
#        [ 1.3437219 ,  1.0286918 ,  0.84062266, ...,  2.8044739 ,
#          2.9833343 ,  3.1278682 ],
#        [ 2.218954  ,  1.8528862 ,  1.4945592 , ...,  1.761933  ,
#          1.8203558 ,  1.8650458 ],
#        ...,
#        [ 1.4901574 ,  1.4945916 ,  1.488247  , ..., -2.1727395 ,
#         -1.9703727 , -1.7858026 ],
#        [ 0.8031295 ,  0.811383  ,  0.85326546, ..., -1.879925  ,
#         -1.5994292 , -1.3403159 ],
#        [ 1.7890778 ,  1.7942424 ,  1.7947894 , ..., -4.2103558 ,
#         -4.0826507 , -3.9582279 ]], shape=(122, 540), dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 976B 2013-04-01 2013-04-02 ... 2013-07-31
#   * XC       (XC) float64 4kB 170.1 170.2 170.4 170.6 ... 259.6 259.8 259.9
#     iter     (time) int64 976B dask.array<chunksize=(1,), meta=np.ndarray>

# %% [markdown]
# ### Window (in X and T)

# %%
# use a hanning window in t and x dimensions
window_t = np.hanning(ADJetan_anom.shape[0])
window_x = np.hanning(ADJetan_anom.shape[1])
window_2d = np.outer(window_t, window_x)
ADJetan_windowed = ADJetan_anom * window_2d
ADJetan_sym_windowed = ADJetan_anom_sym * window_2d
ADJetan_anti_windowed = ADJetan_anom_anti * window_2d
# ADJqnet_windowed = ADJqnet_anom * window_2d

# window_t = np.hanning(ADJtaux_anom.shape[0])
# window_x = np.hanning(ADJtaux_anom.shape[1])
# window_2d = np.outer(window_t, window_x)
# ADJtaux_windowed = ADJtaux_anom * window_2d

# %%
folder_name = '/home/edavenport/analysis/yannai-waves/'

# %% [markdown]
# ### 2-D FFT

# %%
# -----------------------------
# Get time and space units (dt and dx) from coordinates
# -----------------------------

dx = np.mean(np.diff(tpose_ds.XC))  # in units of degrees
dt_ns = np.mean(np.diff(tpose_ds.time))              # timedelta64[ns]
dt = dt_ns / np.timedelta64(1, 'D') # convert to float in days

print(dt)    # 1 day
print(dx)    # 1/6 degree
# Out:
# 1.0
# 0.16666665723018612

# %%
# # -----------------------------
# # 2D FFT
# # -----------------------------
ETAN_fft = np.fft.fft2(ADJetan_windowed)
ETAN_fft = np.fft.fftshift(ETAN_fft, axes=(0,1))  # shift time and lon axes
Nt = ADJetan_windowed.shape[0]
Nx = ADJetan_windowed.shape[1]
P = np.abs(ETAN_fft)**2 / (Nt*Nx)

ETAN_sym_fft = np.fft.fft2(ADJetan_sym_windowed)
ETAN_sym_fft = np.fft.fftshift(ETAN_sym_fft, axes=(0,1))  # shift time and lon axes
P_sym = np.abs(ETAN_sym_fft)**2 / (Nt*Nx)

ETAN_anti_fft = np.fft.fft2(ADJetan_anti_windowed)
ETAN_anti_fft = np.fft.fftshift(ETAN_anti_fft, axes=(0,1))  # shift time and lon axes
P_anti = np.abs(ETAN_anti_fft)**2 / (Nt*Nx)

# %%
# wavenumber / frequency axes
kx = np.fft.fftshift(np.fft.fftfreq(Nx, d=dx))        # deg^-1
omega = np.fft.fftshift(np.fft.fftfreq(Nt, d=dt)) # cycles/day
# omega_rad_per_day = 2*np.pi*omega

# %%
# -----------------------------
# Normalize for real signal
# -----------------------------
# double all non-zero, non-Nyquist frequencies along time
nonzero_idx = np.where((omega != 0) & (omega != omega.max()))[0]
P[nonzero_idx, :] *= 2

# -----------------------------
# Select only positive omega
# -----------------------------
pos_idx = omega >= 0
P_pos = P[pos_idx, :]
omega_pos = omega[pos_idx]
# omega_rad_per_day_pos = omega_rad_per_day[pos_idx]

# Create xarray for plotting
P_da = xr.DataArray(P_pos, dims=['omega','kx'],
                    coords={'omega': omega_pos, 'kx': kx})

P_sym[nonzero_idx, :] *= 2

# -----------------------------
# Select only positive omega
# -----------------------------
pos_idx = omega >= 0
P_pos = P_sym[pos_idx, :]

# Create xarray for plotting
P_da_sym = xr.DataArray(P_pos, dims=['omega','kx'],
                    coords={'omega': omega_pos, 'kx': kx})

P_anti[nonzero_idx, :] *= 2

# -----------------------------
# Select only positive omega
# -----------------------------
pos_idx = omega >= 0
P_pos = P_anti[pos_idx, :]
# Create xarray for plotting
P_da_anti = xr.DataArray(P_pos, dims=['omega','kx'],
                    coords={'omega': omega_pos, 'kx': kx})

# %%
fig, ax = plt.subplots(figsize=(12,5),ncols=3)
P_da.plot(ax=ax[0],x='kx', y='omega', cmap='viridis',vmax=np.percentile(P_da, 99))
ax[0].set_xlim(-1,1)
# ax[0].set_ylim(0,0.5)
P_da_sym.plot(ax=ax[1],x='kx', y='omega', cmap='viridis',vmax=np.percentile(P_da, 99))
ax[1].set_xlim(-1,1)
# ax[1].set_ylim(0,0.5)
P_da_anti.plot(ax=ax[2],x='kx', y='omega', cmap='viridis',vmax=np.percentile(P_da, 99))
ax[2].set_xlim(-1,1)
# ax[2].set_ylim(0,0.5)
plt.tight_layout()

# %%
# -----------------------------
# Physical constants
# -----------------------------
g = 9.81            # m/s^2
beta = 2.3e-11      # 1/(m s)
c1 = 2.5
c2 = 1.4
deg2m = 111320      # m per degree at equator
c_barotropic = np.sqrt(9.81*4000)  # m/s

# %%
# # --- Dispersion relations --- in rad/s
def omega_kelvin_fn(k, c): 
#     # Kelvin waves exist for eastward (positive k) only
    omega = np.zeros_like(k)
    omega[k>=0] = c*k[k>=0]
    omega[k<0] = np.nan  # optional: don't plot Kelvin for negative k
    return omega

def omega_yanai(k, c, beta): 
    return 0.5*(c*k - np.sqrt((c*k)**2 + 4*beta*c))

def omega_yanai_east(k, c, beta): 
    return 0.5*(c*k + np.sqrt((c*k)**2 + 4*beta*c))

def omega_rossby_fn(k, n, c, beta): 
    return - beta*k / (k**2 + (2*n + 1)*beta/c)

def omega_IG(k, n, c, beta): 
    return np.sqrt(c**2 * k**2 + (2*n + 1)*beta*c)

# %%
deg2m = 111320      # m per degree at equator
k_rad = 2*np.pi * kx / deg2m  # convert to rad/m

# --- Plotting ---
plt.figure(figsize=(6,6))

# Kelvin (eastward only)
plt.plot(kx, omega_kelvin_fn(k_rad, c1)*86400, label="Kelvin n=-1")

# Yanai
plt.plot(kx, omega_yanai(k_rad, c1, beta)*86400, label="Yanai n=0 (west)")
plt.plot(kx, omega_yanai_east(k_rad, c1, beta)*86400, label="Yanai n=0 (east)")

# Rossby n=1..3
for n in [1,2,3]:
    plt.plot(kx, omega_rossby_fn(k_rad, n, c1, beta)*86400, label=f"Rossby n={n}")

# IG n=1..3
for n in [1,2,3]:
    plt.plot(kx, omega_IG(k_rad, n, c1, beta)*86400, label=f"IG n={n}")

plt.xlabel("Zonal wavenumber k [deg$^{-1}$] (positive = east, negative = west)")
plt.ylabel("Frequency ω [rad/day]")
plt.title("Equatorial Wave Dispersion Curves (first baroclinic mode)")
plt.legend()
plt.xlim(-1, 1)
plt.ylim(0, 1.0)
plt.grid(True)
plt.show()

# %%
deg2m = 111320      # m per degree at equator
k_rad = 2*np.pi * kx / deg2m  # convert to rad/m
omega_barotropic = -beta * k_rad / (k_rad**2 + 1 * beta / c_barotropic)  # rad/s

from matplotlib.colors import LogNorm
log_levels = np.logspace(1, 4, 100)
fig, ax = plt.subplots(figsize=(12,6))
cf = P_da.plot.contourf(ax=ax,x='kx', y='omega', cmap=cmo.ice,levels=log_levels,extend='both',norm=LogNorm(vmin=1e1,vmax=1e4))

# set log scale ticks for colorbar
cbar = cf.colorbar
cbar.set_ticks([10, 100, 1000, 10000])

ax.set_ylabel('Frequency (cycles/day)')
ax.set_xlabel('Zonal wavenumber (deg$^{-1}$)')
# Overlay dispersion curves
ax.plot(kx, omega_barotropic*86400/(2*np.pi), color='gray', linestyle='--', label='Barotropic Rossby')
ax.plot(kx, omega_kelvin_fn(k_rad, c1)*86400/(2*np.pi), color='orange', label='Kelvin m=1')
ax.plot(kx, omega_kelvin_fn(k_rad, c2)*86400/(2*np.pi), color='orange', linestyle='--',label='Kelvin m=2')
ax.plot(kx, omega_yanai_east(k_rad, c1, beta)*86400/(2*np.pi), color='green', linestyle='--',label='Yanai n=0, m=1')
ax.plot(kx, omega_yanai_east(k_rad, c2, beta)*86400/(2*np.pi), color='green', linestyle='-.', label='Yanai n=0, m=2')
ax.plot(kx, omega_rossby_fn(k_rad, 1, c1, beta)*86400/(2*np.pi), color='blue', linestyle='--', label='Rossby n=1,m=1')
ax.plot(kx, omega_rossby_fn(k_rad, 2, c1, beta)*86400/(2*np.pi), color='blue', linestyle='-.', label='Rossby n=2,m=1')
ax.plot(kx, omega_rossby_fn(k_rad, 3, c1, beta)*86400/(2*np.pi), color='blue', linestyle=':', label='Rossby n=3,m=1')
ax.plot(kx, omega_IG(k_rad, 0, c1, beta)*86400/(2*np.pi), color='m', linestyle='--', label='IGW n=0,m=1')
ax.plot(kx, omega_IG(k_rad, 1, c1, beta)*86400/(2*np.pi), color='m', linestyle='-.', label='IGW n=1,m=1')
ax.plot(kx, omega_IG(k_rad, 0, c2, beta)*86400/(2*np.pi), color='m', linestyle=':', label='IGW n=0,m=2')
ax.plot(kx, omega_IG(k_rad, 1, c2, beta)*86400/(2*np.pi), color='m', label='IGW n=1,m=2')
ax.axvline(0, color='k',label='_nolabel')
ax.legend(bbox_to_anchor=(1.5, 0.5))

# Manually set secondary x-axis ticks
km_ticks = np.array([-4000, -500, 500, 4000])  # desired top-axis tick labels in km
kdeg_for_ticks = deg2m / (1000 * km_ticks)     # convert km → k_deg
# Set secondary axis manually with fixed tick positions
secax = ax.secondary_xaxis('top')
secax.set_xticks(kdeg_for_ticks)                  # positions in deg^-1
secax.set_xticklabels([str(int(wl)) for wl in km_ticks])  # labels in km
secax.set_xlabel('Zonal wavelength (km)')

ax.set_xlim(-0.3,0.3)
ax.set_ylim(0,0.5)

plt.tight_layout()
fig.savefig(folder_name + 'k_omega_spectrum_TEST.png', dpi=300)

# %%
deg2m = 111320      # m per degree at equator
k_rad = 2*np.pi * kx / deg2m  # convert to rad/m
omega_barotropic = -beta * k_rad / (k_rad**2 + 1 * beta / c_barotropic)  # rad/s

from matplotlib.colors import LogNorm
log_levels = np.logspace(1, 4, 100)
fig, ax = plt.subplots(figsize=(12,6))
cf = P_da_sym.plot.contourf(ax=ax,x='kx', y='omega', cmap=cmo.ice,levels=log_levels,extend='both',norm=LogNorm(vmin=1e1,vmax=1e4))

# set log scale ticks for colorbar
cbar = cf.colorbar
cbar.set_ticks([10, 100, 1000, 10000])

ax.set_ylabel('Frequency (cycles/day)')
ax.set_xlabel('Zonal wavenumber (deg$^{-1}$)')
# Overlay dispersion curves
ax.plot(kx, omega_barotropic*86400/(2*np.pi), color='gray', linestyle='--', label='Barotropic Rossby')
ax.plot(kx, omega_kelvin_fn(k_rad, c1)*86400/(2*np.pi), color='orange', label='Kelvin m=1')
ax.plot(kx, omega_kelvin_fn(k_rad, c2)*86400/(2*np.pi), color='orange', linestyle='--',label='Kelvin m=2')
ax.plot(kx, omega_yanai_east(k_rad, c1, beta)*86400/(2*np.pi), color='green', linestyle='--',label='Yanai n=0, m=1')
ax.plot(kx, omega_yanai_east(k_rad, c2, beta)*86400/(2*np.pi), color='green', linestyle='-.', label='Yanai n=0, m=2')
ax.plot(kx, omega_rossby_fn(k_rad, 1, c1, beta)*86400/(2*np.pi), color='blue', linestyle='--', label='Rossby n=1,m=1')
ax.plot(kx, omega_rossby_fn(k_rad, 2, c1, beta)*86400/(2*np.pi), color='blue', linestyle='-.', label='Rossby n=2,m=1')
ax.plot(kx, omega_rossby_fn(k_rad, 3, c1, beta)*86400/(2*np.pi), color='blue', linestyle=':', label='Rossby n=3,m=1')
ax.plot(kx, omega_IG(k_rad, 0, c1, beta)*86400/(2*np.pi), color='m', linestyle='--', label='IGW n=0,m=1')
ax.plot(kx, omega_IG(k_rad, 1, c1, beta)*86400/(2*np.pi), color='m', linestyle='-.', label='IGW n=1,m=1')
ax.plot(kx, omega_IG(k_rad, 0, c2, beta)*86400/(2*np.pi), color='m', linestyle=':', label='IGW n=0,m=2')
ax.plot(kx, omega_IG(k_rad, 1, c2, beta)*86400/(2*np.pi), color='m', label='IGW n=1,m=2')
ax.axvline(0, color='k',label='_nolabel')
ax.legend(bbox_to_anchor=(1.5, 0.5))

# Manually set secondary x-axis ticks
km_ticks = np.array([-4000, -500, 500, 4000])  # desired top-axis tick labels in km
kdeg_for_ticks = deg2m / (1000 * km_ticks)     # convert km → k_deg
# Set secondary axis manually with fixed tick positions
secax = ax.secondary_xaxis('top')
secax.set_xticks(kdeg_for_ticks)                  # positions in deg^-1
secax.set_xticklabels([str(int(wl)) for wl in km_ticks])  # labels in km
secax.set_xlabel('Zonal wavelength (km)')

ax.set_xlim(-0.3,0.3)
ax.set_ylim(0,0.5)

plt.tight_layout()
fig.savefig(folder_name + 'k_omega_spectrum_TEST_symmetric.png', dpi=300)

# %%
deg2m = 111320      # m per degree at equator
k_rad = 2*np.pi * kx / deg2m  # convert to rad/m
omega_barotropic = -beta * k_rad / (k_rad**2 + 1 * beta / c_barotropic)  # rad/s

from matplotlib.colors import LogNorm
log_levels = np.logspace(1, 4, 100)
fig, ax = plt.subplots(figsize=(12,6))
cf = P_da_anti.plot.contourf(ax=ax,x='kx', y='omega', cmap=cmo.ice,levels=log_levels,extend='both',norm=LogNorm(vmin=1e1,vmax=1e4))

# set log scale ticks for colorbar
cbar = cf.colorbar
cbar.set_ticks([10, 100, 1000, 10000])

ax.set_ylabel('Frequency (cycles/day)')
ax.set_xlabel('Zonal wavenumber (deg$^{-1}$)')
# Overlay dispersion curves
ax.plot(kx, omega_barotropic*86400/(2*np.pi), color='gray', linestyle='--', label='Barotropic Rossby')
ax.plot(kx, omega_kelvin_fn(k_rad, c1)*86400/(2*np.pi), color='orange', label='Kelvin m=1')
ax.plot(kx, omega_kelvin_fn(k_rad, c2)*86400/(2*np.pi), color='orange', linestyle='--',label='Kelvin m=2')
ax.plot(kx, omega_yanai_east(k_rad, c1, beta)*86400/(2*np.pi), color='green', linestyle='--',label='Yanai n=0, m=1')
ax.plot(kx, omega_yanai_east(k_rad, c2, beta)*86400/(2*np.pi), color='green', linestyle='-.', label='Yanai n=0, m=2')
ax.plot(kx, omega_rossby_fn(k_rad, 1, c1, beta)*86400/(2*np.pi), color='blue', linestyle='--', label='Rossby n=1,m=1')
ax.plot(kx, omega_rossby_fn(k_rad, 2, c1, beta)*86400/(2*np.pi), color='blue', linestyle='-.', label='Rossby n=2,m=1')
ax.plot(kx, omega_rossby_fn(k_rad, 3, c1, beta)*86400/(2*np.pi), color='blue', linestyle=':', label='Rossby n=3,m=1')
ax.plot(kx, omega_IG(k_rad, 0, c1, beta)*86400/(2*np.pi), color='m', linestyle='--', label='IGW n=0,m=1')
ax.plot(kx, omega_IG(k_rad, 1, c1, beta)*86400/(2*np.pi), color='m', linestyle='-.', label='IGW n=1,m=1')
ax.plot(kx, omega_IG(k_rad, 0, c2, beta)*86400/(2*np.pi), color='m', linestyle=':', label='IGW n=0,m=2')
ax.plot(kx, omega_IG(k_rad, 1, c2, beta)*86400/(2*np.pi), color='m', label='IGW n=1,m=2')
ax.axvline(0, color='k',label='_nolabel')
ax.legend(bbox_to_anchor=(1.5, 0.5))

# Manually set secondary x-axis ticks
km_ticks = np.array([-4000, -500, 500, 4000])  # desired top-axis tick labels in km
kdeg_for_ticks = deg2m / (1000 * km_ticks)     # convert km → k_deg
# Set secondary axis manually with fixed tick positions
secax = ax.secondary_xaxis('top')
secax.set_xticks(kdeg_for_ticks)                  # positions in deg^-1
secax.set_xticklabels([str(int(wl)) for wl in km_ticks])  # labels in km
secax.set_xlabel('Zonal wavelength (km)')

ax.set_xlim(-0.3,0.3)
ax.set_ylim(0,0.5)

plt.tight_layout()
fig.savefig(folder_name + 'k_omega_spectrum_TEST_anti.png', dpi=300)

# %%
cluster.close()
client.shutdown()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cluster.close()
#       2 client.shutdown()
#
# NameError: name 'cluster' is not defined

# %%
from dask.distributed import LocalCluster, Client
cluster = LocalCluster()
client = Client(cluster)

foldername = '/home/edavenport/analysis/yannai-waves/with_spring_2013/shear_prof/'

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 13
import cmocean.cm as cmo
import xarray as xr
from open_tpose import tpose2012to2013
import numpy as np
import xarray as xr

prefix = ['diag_state','diag_surf']
ds_tpose_noTAO = tpose2012to2013(prefix)

ds_tpose_noTAO['XC'] = ds_tpose_noTAO.XC.astype(float)
ds_tpose_noTAO['YC'] = ds_tpose_noTAO.YC.astype(float)
ds_tpose_noTAO['Z'] = ds_tpose_noTAO.Z.astype(float)
ds_tpose_noTAO['XG'] = ds_tpose_noTAO.XG.astype(float)
ds_tpose_noTAO['YG'] = ds_tpose_noTAO.YG.astype(float)

from xmitgcm import open_mdsdataset
data_dir = '/data/SO3/edavenport/tpose6/sep2012/velocity_assim/run_iter22/'
grid_dir = '/data/SO6/TPOSE_diags/tpose6/grid_6/'

offset = 10
num_diags = 30+31+offset #sep, oct + 10 days
itPerFile = 72 # 1 day
intervals = range(itPerFile,itPerFile*num_diags,itPerFile)

prefix = ['diag_state','diag_surf']
ds = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2012-09-01',delta_t=1200)

num_diags = 30+31+offset# nov, dec (starting from nov 10)
itPerFile = 72 # 1 day
intervals = range(itPerFile*offset,itPerFile*num_diags,itPerFile)

data_dir = '/data/SO3/edavenport/tpose6/nov2012/run_iter20/'
ds_new = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2012-11-01',delta_t=1200)

ds_tpose_TAO = xr.concat([ds,ds_new],dim='time')

num_diags = 31+28+offset # jan, feb, (starting from jan 10)
itPerFile = 72 # 1 day
intervals = range(itPerFile*offset,itPerFile*num_diags,itPerFile)

data_dir = '/data/SO3/edavenport/tpose6/jan2013/run_iter14/'
ds_new = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2013-01-01',delta_t=1200)

ds_tpose_TAO = xr.concat([ds_tpose_TAO,ds_new],dim='time')

num_diags = 31+30+31+30 # mar, apr, may, june (starting from jan 10)
itPerFile = 72 # 1 day
intervals = range(itPerFile*offset,itPerFile*num_diags,itPerFile)

data_dir = '/data/SO3/edavenport/tpose6/mar2013/run_iter16/'
ds_new = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2013-03-01',delta_t=1200)

ds_tpose_TAO = xr.concat([ds_tpose_TAO,ds_new],dim='time')

ds_tpose_TAO['XC'] = ds_tpose_TAO.XC.astype(float)
ds_tpose_TAO['YC'] = ds_tpose_TAO.YC.astype(float)
ds_tpose_TAO['Z'] = ds_tpose_TAO.Z.astype(float)
ds_tpose_TAO['XG'] = ds_tpose_TAO.XG.astype(float)
ds_tpose_TAO['YG'] = ds_tpose_TAO.YG.astype(float)

ds_tpose_noTAO = ds_tpose_noTAO.sel(time=slice('2012-09-01','2013-06-29'))
# Out:
# mar2013/diags_daily/
# may2013/diags_daily/
# jul2013/diags_daily/
# sep2013/diags_daily/
# nov2013/diags_daily/
# Days in 2012-2013: (should be 731)
# 731

# %%
# tpose_ds.ADJetan is t, xc, YG
lat_min = -5
lat_max = 5
lon_min = 170 #170E
lon_max = 260 #100W

ds_tpose_TAO = ds_tpose_TAO.sel(XC=slice(lon_min,lon_max),YC=slice(lat_min,lat_max),XG=slice(lon_min,lon_max),YG=slice(lat_min,lat_max))
ds_tpose_noTAO = ds_tpose_noTAO.sel(XC=slice(lon_min,lon_max),YC=slice(lat_min,lat_max),XG=slice(lon_min,lon_max),YG=slice(lat_min,lat_max))

# %%
# lon = 220
lat = 0.0

# %% [markdown]
# ### Plot Vertical Shear at 5 locations before and after TAO

# %%
var_name = 'UVEL'
lat_dim = 'YC'
lon_dim = 'XG'
# 10 panes, row 1 is 5 locations of uvel shear and row 2 is 5 locations of vvel shear
fig, axs = plt.subplots(2,5,figsize=(20,10),sharey=True)
for i,lon in enumerate([190,205,220,235,250]):
    ds_tpose_TAO_shear = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').mean(dim='time')
    ds_tpose_TAO_shear_std = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').std(dim='time')
    ds_tpose_noTAO_shear = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').mean(dim='time')
    ds_tpose_noTAO_shear_std = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').std(dim='time')
    axs[0,i].set_title(f'{var_name} shear at {lat}N°{lon}E°')
    axs[0,i].plot(ds_tpose_TAO_shear,ds_tpose_TAO.Z,color='blue',label='TAO')
    axs[0,i].fill_betweenx(ds_tpose_TAO.Z,ds_tpose_TAO_shear-ds_tpose_TAO_shear_std,ds_tpose_TAO_shear+ds_tpose_TAO_shear_std,color='blue',alpha=0.3)
    axs[0,i].plot(ds_tpose_noTAO_shear,ds_tpose_noTAO.Z,color='red',label='no TAO',ls='--')
    axs[0,i].fill_betweenx(ds_tpose_noTAO.Z,ds_tpose_noTAO_shear-ds_tpose_noTAO_shear_std,ds_tpose_noTAO_shear+ds_tpose_noTAO_shear_std,color='red',alpha=0.3)
    axs[0,i].set_xlim(-0.5,0.5)
    axs[0,i].set_xlabel('')

axs[0,0].legend()

lat = 0.0
var_name = 'VVEL'
lat_dim = 'YG'
lon_dim = 'XC'
for i,lon in enumerate([190,205,220,235,250]):
    ds_tpose_TAO_shear = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').mean(dim='time')
    ds_tpose_TAO_shear_std = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').std(dim='time')
    ds_tpose_noTAO_shear = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').mean(dim='time')
    ds_tpose_noTAO_shear_std = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').std(dim='time')
    axs[1,i].set_title(f'{var_name} shear at {lat}N°{lon}E°')
    axs[1,i].plot(ds_tpose_TAO_shear,ds_tpose_TAO.Z,color='blue',label='TAO')
    axs[1,i].fill_betweenx(ds_tpose_TAO.Z,ds_tpose_TAO_shear-ds_tpose_TAO_shear_std,ds_tpose_TAO_shear+ds_tpose_TAO_shear_std,color='blue',alpha=0.3)
    axs[1,i].plot(ds_tpose_noTAO_shear,ds_tpose_noTAO.Z,color='red',label='no TAO',ls='--')
    axs[1,i].fill_betweenx(ds_tpose_noTAO.Z,ds_tpose_noTAO_shear-ds_tpose_noTAO_shear_std,ds_tpose_noTAO_shear+ds_tpose_noTAO_shear_std,color='red',alpha=0.3)
    axs[1,i].set_xlim(-0.25,0.25)
    axs[1,i].set_xlabel('Shear (1/s)')

axs[1,0].legend()

for ax in axs.flatten():
    ax.axvline(0,color='black',lw=0.5)

plt.tight_layout()
plt.savefig(foldername + 'vel_comparison.png',dpi=300)

# %%
var_name = 'UVEL'
lat_dim = 'YC'
lon_dim = 'XG'
# 10 panes, row 1 is 5 locations of uvel shear and row 2 is 5 locations of vvel shear
fig, axs = plt.subplots(2,5,figsize=(20,10),sharey=True)
for i,lon in enumerate([190,205,220,235,250]):
    ds_tpose_TAO_shear = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').mean(dim='time')
    ds_tpose_TAO_shear_std = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').std(dim='time')
    ds_tpose_noTAO_shear = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').mean(dim='time')
    ds_tpose_noTAO_shear_std = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').std(dim='time')
    axs[0,i].set_title(f'{var_name} shear at {lat}N°{lon}E°')
    axs[0,i].plot(ds_tpose_TAO_shear,ds_tpose_TAO.Z,color='blue',label='TAO')
    axs[0,i].fill_betweenx(ds_tpose_TAO.Z,ds_tpose_TAO_shear-ds_tpose_TAO_shear_std,ds_tpose_TAO_shear+ds_tpose_TAO_shear_std,color='blue',alpha=0.3)
    axs[0,i].plot(ds_tpose_noTAO_shear,ds_tpose_noTAO.Z,color='red',label='no TAO',ls='--')
    axs[0,i].fill_betweenx(ds_tpose_noTAO.Z,ds_tpose_noTAO_shear-ds_tpose_noTAO_shear_std,ds_tpose_noTAO_shear+ds_tpose_noTAO_shear_std,color='red',alpha=0.3)
    axs[0,i].set_xlim(-0.5,1.7)
    axs[0,i].set_xlabel('')

axs[0,0].legend()

lat = 0.0
var_name = 'VVEL'
lat_dim = 'YG'
lon_dim = 'XC'
for i,lon in enumerate([190,205,220,235,250]):
    ds_tpose_TAO_shear = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').mean(dim='time')
    ds_tpose_TAO_shear_std = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').std(dim='time')
    ds_tpose_noTAO_shear = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').mean(dim='time')
    ds_tpose_noTAO_shear_std = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').std(dim='time')
    axs[1,i].set_title(f'{var_name} shear at {lat}N°{lon}E°')
    axs[1,i].plot(ds_tpose_TAO_shear,ds_tpose_TAO.Z,color='blue',label='TAO')
    axs[1,i].fill_betweenx(ds_tpose_TAO.Z,ds_tpose_TAO_shear-ds_tpose_TAO_shear_std,ds_tpose_TAO_shear+ds_tpose_TAO_shear_std,color='blue',alpha=0.3)
    axs[1,i].plot(ds_tpose_noTAO_shear,ds_tpose_noTAO.Z,color='red',label='no TAO',ls='--')
    axs[1,i].fill_betweenx(ds_tpose_noTAO.Z,ds_tpose_noTAO_shear-ds_tpose_noTAO_shear_std,ds_tpose_noTAO_shear+ds_tpose_noTAO_shear_std,color='red',alpha=0.3)
    axs[1,i].set_xlim(-0.5,0.5)
    axs[1,i].set_xlabel('Shear (1/s)')

axs[1,0].legend()

for ax in axs.flatten():
    ax.axvline(0,color='black',lw=0.5)
    ax.set_ylim(-750,0)

plt.tight_layout()
plt.savefig(foldername + 'vel_comparison_750m.png',dpi=300)

# %%
var_name = 'UVEL'
lat_dim = 'YC'
lon_dim = 'XG'
# 10 panes, row 1 is 5 locations of uvel shear and row 2 is 5 locations of vvel shear
fig, axs = plt.subplots(2,5,figsize=(20,10),sharey=True)
for i,lon in enumerate([190,205,220,235,250]):
    ds_tpose_TAO_shear = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').mean(dim='time')
    ds_tpose_TAO_shear_std = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').std(dim='time')
    ds_tpose_noTAO_shear = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').mean(dim='time')
    ds_tpose_noTAO_shear_std = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').std(dim='time')
    axs[0,i].set_title(f'{var_name} shear at {lat}N°{lon}E°')
    axs[0,i].plot(ds_tpose_TAO_shear,ds_tpose_TAO.Z[:-1],color='blue',label='TAO')
    axs[0,i].fill_betweenx(ds_tpose_TAO.Z[:-1],ds_tpose_TAO_shear-ds_tpose_TAO_shear_std,ds_tpose_TAO_shear+ds_tpose_TAO_shear_std,color='blue',alpha=0.3)
    axs[0,i].plot(ds_tpose_noTAO_shear,ds_tpose_noTAO.Z[:-1],color='red',label='no TAO',ls='--')
    axs[0,i].fill_betweenx(ds_tpose_noTAO.Z[:-1],ds_tpose_noTAO_shear-ds_tpose_noTAO_shear_std,ds_tpose_noTAO_shear+ds_tpose_noTAO_shear_std,color='red',alpha=0.3)
    axs[0,i].set_xlim(-0.2,0.2)
    axs[0,i].set_xlabel('')

axs[0,0].legend()

lat = 0.0
var_name = 'VVEL'
lat_dim = 'YG'
lon_dim = 'XC'
for i,lon in enumerate([190,205,220,235,250]):
    ds_tpose_TAO_shear = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').mean(dim='time')
    ds_tpose_TAO_shear_std = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').std(dim='time')
    ds_tpose_noTAO_shear = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').mean(dim='time')
    ds_tpose_noTAO_shear_std = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').std(dim='time')
    axs[1,i].set_title(f'{var_name} shear at {lat}N°{lon}E°')
    axs[1,i].plot(ds_tpose_TAO_shear,ds_tpose_TAO.Z[:-1],color='blue',label='TAO')
    axs[1,i].fill_betweenx(ds_tpose_TAO.Z[:-1],ds_tpose_TAO_shear-ds_tpose_TAO_shear_std,ds_tpose_TAO_shear+ds_tpose_TAO_shear_std,color='blue',alpha=0.3)
    axs[1,i].plot(ds_tpose_noTAO_shear,ds_tpose_noTAO.Z[:-1],color='red',label='no TAO',ls='--')
    axs[1,i].fill_betweenx(ds_tpose_noTAO.Z[:-1],ds_tpose_noTAO_shear-ds_tpose_noTAO_shear_std,ds_tpose_noTAO_shear+ds_tpose_noTAO_shear_std,color='red',alpha=0.3)
    axs[1,i].set_xlim(-0.03,0.03)
    axs[1,i].set_xlabel('Shear (1/s)')

axs[1,0].legend()

for ax in axs.flatten():
    ax.axvline(0,color='black',lw=0.5)

plt.tight_layout()
plt.savefig(foldername + 'shear_comparison.png',dpi=300)

# %%
# 10 panes, row 1 is 5 locations of uvel shear and row 2 is 5 locations of vvel shear
var_name = 'UVEL'
lat_dim = 'YC'
lon_dim = 'XG'
fig, axs = plt.subplots(2,5,figsize=(20,10),sharey=True)
for i,lon in enumerate([190,205,220,235,250]):
    ds_tpose_TAO_shear = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').mean(dim='time')
    ds_tpose_TAO_shear_std = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').std(dim='time')
    ds_tpose_noTAO_shear = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').mean(dim='time')
    ds_tpose_noTAO_shear_std = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').std(dim='time')
    axs[0,i].set_title(f'{var_name} shear at {lat}N°{lon}E°')
    axs[0,i].plot(ds_tpose_TAO_shear,ds_tpose_TAO.Z[:-1],color='blue',label='TAO')
    axs[0,i].fill_betweenx(ds_tpose_TAO.Z[:-1],ds_tpose_TAO_shear-ds_tpose_TAO_shear_std,ds_tpose_TAO_shear+ds_tpose_TAO_shear_std,color='blue',alpha=0.3)
    axs[0,i].plot(ds_tpose_noTAO_shear,ds_tpose_noTAO.Z[:-1],color='red',label='no TAO',ls='--')
    axs[0,i].fill_betweenx(ds_tpose_noTAO.Z[:-1],ds_tpose_noTAO_shear-ds_tpose_noTAO_shear_std,ds_tpose_noTAO_shear+ds_tpose_noTAO_shear_std,color='red',alpha=0.3)
    axs[0,i].set_xlim(-0.25,0.25)
    axs[0,i].set_xlabel('')

axs[0,0].legend()

lat = 0.0
var_name = 'VVEL'
lat_dim = 'YG'
lon_dim = 'XC'
for i,lon in enumerate([190,205,220,235,250]):
    ds_tpose_TAO_shear = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').mean(dim='time')
    ds_tpose_TAO_shear_std = ds_tpose_TAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').std(dim='time')
    ds_tpose_noTAO_shear = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').mean(dim='time')
    ds_tpose_noTAO_shear_std = ds_tpose_noTAO[var_name].sel({lat_dim:lat,lon_dim:lon},method='nearest').diff(dim='Z').std(dim='time')
    axs[1,i].set_title(f'{var_name} shear at {lat}N°{lon}E°')
    axs[1,i].plot(ds_tpose_TAO_shear,ds_tpose_TAO.Z[:-1],color='blue',label='TAO')
    axs[1,i].fill_betweenx(ds_tpose_TAO.Z[:-1],ds_tpose_TAO_shear-ds_tpose_TAO_shear_std,ds_tpose_TAO_shear+ds_tpose_TAO_shear_std,color='blue',alpha=0.3)
    axs[1,i].plot(ds_tpose_noTAO_shear,ds_tpose_noTAO.Z[:-1],color='red',label='no TAO',ls='--')
    axs[1,i].fill_betweenx(ds_tpose_noTAO.Z[:-1],ds_tpose_noTAO_shear-ds_tpose_noTAO_shear_std,ds_tpose_noTAO_shear+ds_tpose_noTAO_shear_std,color='red',alpha=0.3)
    axs[1,i].set_xlim(-0.05,0.05)
    axs[1,i].set_xlabel('Shear (1/s)')

axs[1,0].legend()

for ax in axs.flatten():
    ax.axvline(0,color='black',lw=0.5)
    ax.set_ylim(-750,0)

plt.tight_layout()
plt.savefig(foldername + 'shear_comparison_750m.png',dpi=300)
# Out:
# 2026-03-12 11:33:32,505 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f91c5166480>, <Task finished name='Task-921743' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:32,513 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f91a81a8540>, <Task finished name='Task-921745' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:32,521 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f91a81aab60>, <Task finished name='Task-921746' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-12 11:33:32,529 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f91a81ab380>, <Task finished name='Task-921749' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-12 11:33:32,537 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f20da1d1e40>, <Task finished name='Task-909157' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:32,547 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f20da1d20c0>, <Task finished name='Task-909160' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:32,555 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f20b3f9b740>, <Task finished name='Task-909162' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-12 11:33:32,563 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f20b3f9b9c0>, <Task finished name='Task-909165' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-12 11:33:32,996 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fe5df665620>, <Task finished name='Task-925454' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:33,004 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fe58a5f9ee0>, <Task finished name='Task-925456' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:33,013 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fe58a5f8a40>, <Task finished name='Task-925459' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-12 11:33:33,022 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fe58a5fa520>, <Task finished name='Task-925461' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-12 11:33:33,339 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fced6548c20>, <Task finished name='Task-947175' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:33,348 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fceb8dcdda0>, <Task finished name='Task-947178' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:33,357 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fce99673a60>, <Task finished name='Task-947180' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-12 11:33:33,365 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fce996728e0>, <Task finished name='Task-947183' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-12 11:33:33,701 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f35dade2480>, <Task finished name='Task-909107' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:33,709 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f35c30fef20>, <Task finished name='Task-909110' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:33,717 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f359b1c8360>, <Task finished name='Task-909112' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-12 11:33:33,725 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f359b1c8900>, <Task finished name='Task-909115' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-12 11:33:34,692 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fd390f5d580>, <Task finished name='Task-916408' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# ...
# 2026-03-12 11:33:36,886 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7faae9d8d300>, <Task finished name='Task-940993' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:36,896 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7faae9d8ce00>, <Task finished name='Task-940995' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-12 11:33:36,905 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7faae9d8e980>, <Task finished name='Task-940998' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-03-12 11:33:37,796 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f7d238ff380>, <Task finished name='Task-907230' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:37,804 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f7cff7c4f40>, <Task finished name='Task-907233' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-03-12 11:33:37,813 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f7cff7c5a80>, <Task finished name='Task-907235' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-03-12 11:33:37,822 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f7cff7c65c0>, <Task finished name='Task-907236' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8

# %%
client.shutdown()
cluster.close()
client.close()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
